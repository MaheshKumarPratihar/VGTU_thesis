# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheshKumarPratihar/VGTU_thesis/blob/main/Google_Studio_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests;


import requests
import json
import os

from google.colab import userdata
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)

# %% [markdown]
# #### 1. It's best practice to keep your API key secure.
# #### 2. You can set it as an environment variable, use Colab's Secrets feature, or paste it directly for quick testing (less secure for production).
#
# #### Option 1: Using Colab Secrets (recommended for API keys)
# - Go to the 'Secrets' tab (lock icon) on the left sidebar in Colab,
# - add a new secret named 'GEMINI_API_KEY' with your API key as the value.
# - Then, uncomment the following line:
# - from google.colab import userdata
# - GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
#
# #### Option 2: Set as an environment variable (e.g., if running locally or pre-set)
# - You would run `export GEMINI_API_KEY='your_api_key_here'` in your terminal
# - before starting your Python script.
# - GEMINI_API_KEY = os.environ.get('GEMINI_API_KEY')
#
# #### Option 3: Directly paste your API key (least secure, only for quick tests)
# - GEMINI_API_KEY = "AIzaSyCJ8N16mlzWCuue5wosdfsdfsdfsdfsdf" - REPLACE WITH YOUR ACTUAL API KEY

# %%
# API KEY
GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')

if not GEMINI_API_KEY or GEMINI_API_KEY == "YOUR_GEMINI_API_KEY":
    raise ValueError("Please replace 'YOUR_GEMINI_API_KEY' with your actual Gemini API key, or set it via Colab Secrets.")


# URL
url = "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent"

# HEADERS
headers = {
    'Content-Type': 'application/json',
    'X-goog-api-key': GEMINI_API_KEY
}

# %%
# Enter the prompt
prompt = input()

# Give prompt as payload

payload = {
    "contents": [
        {
            "parts": [
                {
                    "text": prompt
                }
            ]
        }
    ]
}

try:
    response = requests.post(url, headers=headers, json=payload)
    response.raise_for_status()  # Raise an exception for HTTP errors (4xx or 5xx)

    data = response.json()
    # print(json.dumps(data, indent=2)) # Uncomment to see the full response

    # Extracting the generated text
    if 'candidates' in data and data['candidates']:
        for candidate in data['candidates']:
            if 'content' in candidate and 'parts' in candidate['content']:
                for part in candidate['content']['parts']:
                    if 'text' in part:
                        print("AI Explanation:", part['text'])
    else:
        print("No content candidates found in the response.")

except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err} - {response.text}")
except requests.exceptions.ConnectionError as conn_err:
    print(f"Connection error occurred: {conn_err}")
except requests.exceptions.Timeout as timeout_err:
    print(f"Timeout error occurred: {timeout_err}")
except requests.exceptions.RequestException as req_err:
    print(f"An unexpected error occurred: {req_err}")
except json.JSONDecodeError as json_err:
    print(f"Failed to decode JSON response: {json_err} - Response text: {response.text}")
# Out:
# Tell me about Lithuania, result should text not markdown file
# AI Explanation: Lithuania, officially the Republic of Lithuania, is a country in the Baltic region of Europe. It's one of the three Baltic states, along with Latvia and Estonia, and is located on the southeastern shore of the Baltic Sea.
#
# **Key Facts:**
#
# *   **Capital:** Vilnius
# *   **Official Language:** Lithuanian
# *   **Population:** Around 2.8 million
# *   **Currency:** Euro (€)
# *   **Government:** Parliamentary Republic
# *   **Joined EU:** 2004
# *   **Joined NATO:** 2004
#
# **Geography:**
#
# Lithuania is a relatively flat country with a mix of forests, lakes, rivers, and agricultural land. The coastline is relatively short. Its geography contributed to its long history of agricultural success.
#
# **History:**
#
# Lithuania has a rich and complex history:
#
# *   **Grand Duchy of Lithuania:** In the Middle Ages, the Grand Duchy of Lithuania was a major power in Eastern Europe, controlling vast territories including parts of modern-day Belarus, Ukraine, and Russia.
# *   **Union with Poland:** Lithuania formed a personal union with Poland, which later evolved into the Polish-Lithuanian Commonwealth, one of the largest and most influential states in Europe during its time.
# *   **Russian Empire:** After the partitions of Poland in the late 18th century, Lithuania came under the control of the Russian Empire.
# *   **Independence:** Lithuania declared its independence on February 16, 1918, after World War I.
# *   **Soviet Occupation:** During World War II, Lithuania was occupied by the Soviet Union in 1940. It was briefly occupied by Nazi Germany before being reoccupied by the Soviet Union after the war.
# *   **Restoration of Independence:** Lithuania regained its independence in 1990, becoming the first Soviet republic to declare independence.
#
# **Culture:**
#
# Lithuanian culture is deeply rooted in its history and traditions. Some notable aspects include:
#
# *   **Language:** Lithuanian is one of the oldest living Indo-European languages, closely related to Latvian.
# *   **Cuisine:** Lithuanian cuisine features hearty dishes often based on potatoes, meat, and dairy products. Popular dishes include *cepelinai* (potato dumplings), *šaltibarščiai* (cold beetroot soup), and *kugelis* (potato pudding).
# *   **Festivals:** Lithuania has a vibrant festival calendar, including Joninės (St. John's Day), Užgavėnės (Shrove Tuesday), and the Vilnius Festival.
# *   **Traditions:** Traditional crafts, folk music, and dances play an important role in Lithuanian culture.
# *   **Religion:** Predominantly Roman Catholic.
#
# **Economy:**
#
# Lithuania has a developed market economy with a focus on services, manufacturing, and agriculture. Key sectors include:
#
# *   **Services:** Tourism, IT, and financial services
# *   **Manufacturing:** Food processing, furniture production, and textiles
# *   **Agriculture:** Grain, dairy, and meat production
#
# **Tourism:**
#
# Lithuania attracts tourists with its:
#
# *   **Historic cities:** Vilnius, with its UNESCO-listed Old Town, and Kaunas, the second-largest city.
# *   **Natural beauty:** The Curonian Spit, a unique sand dune peninsula shared with Russia, is a UNESCO World Heritage Site. Trakai, with its island castle.
# *   **Culture:** Museums, theaters, and festivals showcasing Lithuanian art, music, and traditions.
# *   **Healthcare and SPA:** Druskininkai resort and other locations are popular for relaxation and health treatments.
#
# **Why is Lithuania important?**
#
# Lithuania plays a significant role in the Baltic region and Europe due to its:
#
# *   **Strategic location:** Situated on the Baltic Sea, it serves as a gateway between Eastern and Western Europe.
# *   **EU and NATO membership:** It is an active member of both organizations, contributing to regional security and economic integration.
# *   **Cultural heritage:** It preserves and promotes its unique language, traditions, and historical legacy.
# *   **Economic development:** It is a growing economy with a skilled workforce and a favorable business environment.
#
# In short, Lithuania is a fascinating country with a rich history, vibrant culture, and a growing economy. It offers a unique blend of traditions and modernity, making it an interesting place to visit and learn about.

# %%
import base64
import os
from google import genai
from google.genai import types

# Enter the prompt
prompt = input()


def generate():
    client = genai.Client(
        api_key=GEMINI_API_KEY,
    )

    model = "gemini-2.5-pro"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text=prompt),
            ],
        ),
    ]
    tools = [
        types.Tool(googleSearch=types.GoogleSearch(
        )),
    ]
    generate_content_config = types.GenerateContentConfig(
        thinking_config = types.ThinkingConfig(
            thinking_budget=-1,
        ),
        tools=tools,
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk.text, end="")

if __name__ == "__main__":
    generate()
# Out:
# Hello where are you from?
# I am a large language model, trained by Google.
